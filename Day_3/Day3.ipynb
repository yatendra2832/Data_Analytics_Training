# %%
import pandas as pd

# data = {
#     "Name": ["Alice", "Bob", "Charlie"],
#     "Age": [25, 30, 35],
#     "City": ["New York", "London", "Paris"]
# }

data = {
    "Name":["Yatendra","Satyam","Neeraj"],
    "Age": [23,22,25],
    "Email":["Yatendra@gmail.com","Satyam@gmail.com","Neeraj@gmail.com"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#        Name  Age               Email
# 0  Yatendra   23  Yatendra@gmail.com
# 1    Satyam   22    Satyam@gmail.com
# 2    Neeraj   25    Neeraj@gmail.com

# %%
# from google.colab import files
# uploaded = files.upload()
import pandas as pd
df = pd.read_csv('data-.csv')
df.head()

print("Mean : ",df['sales'].mean())
print("Median : ",df['sales'].median())
print("Mode : ",df['sales'].mode())
# Out:
# Mean :  214.0
# Median :  200.0
# Mode :  0    200
# Name: sales, dtype: int64

# %%
import numpy as np
arr = np.array([10,20,30,40,50,60])
print("Original Array : ",arr)
print("Sum", np.sum(arr))
print("Mean",np.mean(arr))
print("Maximum : ",np.max(arr))
print("Minimum : ", np.min(arr))
reshaped_arr = arr.reshape(2,3)
print(reshaped_arr)
result = arr*2
print(result)
# Out:
# Original Array :  [10 20 30 40 50 60]
# Sum 210
# Mean 35.0
# Maximum :  60
# Minimum :  10
# [[10 20 30]
#  [40 50 60]]
# [ 20  40  60  80 100 120]

# %%
import numpy as np

# Create two matrices
A = np.array([[1, 2, 3],
              [4, 5, 6]])

B = np.array([[7, 8, 9],
              [1, 2, 3]])

print("Matrix A:")
print(A)

print("\nMatrix B:")
print(B)

# Addition
print("\nAddition (A + B):")
print(A + B)

# Subtraction
print("\nSubtraction (A - B):")
print(A - B)

B2 = np.array([[7, 8],
               [9, 1],
               [2, 3]])

print("\nMatrix B2 (for multiplication):")
print(B2)

print("\nMatrix Multiplication (A x B2):")
print(np.dot(A, B2))
print("\nTranspose of Matrix A:")
print(A.T)
# Out:
# Matrix A:
# [[1 2 3]
#  [4 5 6]]
#
# Matrix B:
# [[7 8 9]
#  [1 2 3]]
#
# Addition (A + B):
# [[ 8 10 12]
#  [ 5  7  9]]
#
# Subtraction (A - B):
# [[-6 -6 -6]
#  [ 3  3  3]]
#
# Matrix B2 (for multiplication):
# [[7 8]
#  [9 1]
#  [2 3]]
#
# Matrix Multiplication (A x B2):
# [[31 19]
#  [85 55]]
#
# Transpose of Matrix A:
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
import numpy as np

arr = np.random.randint(0, 100, 10)

print("Random Array:")
print(arr)

print("Mean:", np.mean(arr))

print("Standard Deviation:", np.std(arr))

print("Minimum Value:", np.min(arr))
print("Maximum Value:", np.max(arr))
# Out:
# Random Array:
# [33 39 80 59 58 35 98 78 68 23]
# Mean: 57.1
# Standard Deviation: 23.05840410783019
# Minimum Value: 23
# Maximum Value: 98

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

x = np.array([1, 2, 3, 4, 5]).reshape(-1,1)
y = np.array([2, 4, 5, 4, 5])

model = LinearRegression()
model.fit(x, y)

print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope: 0.6
# Intercept: 2.2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample Data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

n = len(x)
m = (n*np.sum(x*y) - np.sum(x)*np.sum(y)) / (n*np.sum(x**2) - (np.sum(x))**2)
c = (np.sum(y) - m*np.sum(x)) / n

print("Slope (m):", m)
print("Intercept (c):", c)


y_pred = m*x + c


plt.figure(figsize=(6,4))
plt.scatter(x, y, color='blue', label="Actual Data")
plt.plot(x, y_pred, color='red', label="Regression Line")

plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Linear Regression Chart")
plt.legend()
plt.grid(True)

plt.show()
# Out:
# Slope (m): 0.6
# Intercept (c): 2.2
